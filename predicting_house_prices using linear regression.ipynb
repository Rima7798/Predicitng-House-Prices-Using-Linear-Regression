# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import lib_oops as lib

# %%
usa=pd.read_csv('USA_Housing.csv')

# %%
usa
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
usa.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
for col_name in usa.columns:
    print(usa[col_name].head())
    st_obj=lib.cal_stats(usa[col_name])
    st_obj.everything()
# Out:
# 0    79545.45857
# 1    79248.64245
# 2    61287.06718
# 3    63345.24005
# 4    59982.19723
# Name: Avg. Area Income, dtype: float64
# Total sum: 342915544.91985
# Count: 5000
# Maximum: 107701.7484
# Minimum: 17796.63119
# Range: 89905.11721
# Mean: 68583.10898397
# Median: 68804.28640499999
# No Mode
# Variance: 113570058.15998553
# Standard Deviation: 10656.92536147202
# Skewness: -0.03369974605287991
# Kurtosis: 0.043110890763585985
# Q1: 61480.56239
# Q3: 75783.33866499999
# IQR: 14302.77627499999
# Lower Whisker: 40026.39797750002
# Uppersker: 97237.50307749998
# Outliers Count: 32
# Variance: 113592776.71532859
# Standard Deviation: 10657.991213888694
# 1 standard deviation range:(57925.12 to 79241.10)--> 68.72% of data
# 2 standard deviation range:(47267.13 to 89899.09)--> 95.40% of data
# 3 standard deviation range:(36609.14 to 100557.08)--> 99.74% of data
# likely follows Nomral Distribution
# 95% Confidence Interval: 68287.71,68878.50
# ...

# %%
usa.isnull

# %% [markdown]
# # ML FLOW
#
# 1. Defining problem statement
# 2. Collecting data
# 3. Reading data in python
# 4. Data Preprocessing
# 5. Defining Input and Output
# 6. Train Test Split
# 7. Training ML Model
# 8. Evaluating Model
# 9. Save Model
# 10. Deploy Model
#
#
#     Overfit ==> memorises training data
#     training accuracy> testing accuracy
#
#     underfit ==> does not learn at all
#     training accuracy & testing accuracy both low
#
#     Best fit ==> best model
#     testing accuracy >= training accuracy

# %%
X=usa.drop('Price',axis=1)
Y=usa['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2,random_state=555)

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3185       66469.36947             4.663863                   6.117542
# 3159       72847.98842             5.947064                   6.459059
# 3102       62088.70090             7.053111                   7.113968
# 120        67310.03695             7.193793                   7.760733
# 2567       57730.32200             5.105381                   9.001899
# ...                ...                  ...                        ...
# 233        60575.16244             5.907566                   6.964616
# 1430       73422.83220             5.327630                   4.693947
# 2628       76113.36653             5.625762                   7.067777
# 1057       71240.25164             5.924127                   8.885192
# 4782       83284.54506             7.609567                   6.309589
#
#       Avg. Area Number of Bedrooms  Area Population
# 3185                          4.13      22670.60862
# ...

# %%
print('X train Shape:',X_train.shape)
print('X test Shape:',X_test.shape)
print('Y train Shape:',Y_train.shape)
print('X test Shape:',Y_test.shape)
# Out:
# X train Shape: (4000, 5)
# X test Shape: (1000, 5)
# Y train Shape: (4000,)
# X test Shape: (1000,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
col_index=0
for i in lr.coef_:
    print(usa.columns[col_index],round(i,2),sep='\t')
    print('slope:',round(1,2))
    col_index+=1
    print('*'*50)
print('Y-intercept:',lr.intercept_)
# Out:
# Avg. Area Income	21.59
# slope: 1
# **************************************************
# Avg. Area House Age	164499.23
# slope: 1
# **************************************************
# Avg. Area Number of Rooms	119970.77
# slope: 1
# **************************************************
# Avg. Area Number of Bedrooms	2059.82
# slope: 1
# **************************************************
# Area Population	15.29
# slope: 1
# **************************************************
# Y-intercept: -2630570.4421591507

# %%
sse=sum(Y_test-y_pred)**2
print('Sum of Squared Error:',sse)
        
mse=sse/len(X_test)
print('Mean Squared Error:',mse)

rmse=np.sqrt(mse)
print('Root Mean Squared Error:',rmse)
# Out:
# Sum of Squared Error: 25431524287278.26
# Mean Squared Error: 25431524287.278263
# Root Mean Squared Error: 159472.64432271218

# %%
income=float(input('What is your income'))
age=float(input('What is your house age'))
rooms=float(input('What is your number of rooms'))
bedroom=float(input('What is your number of bedrooms'))
pop=float(input('What is your area population'))
user_input=np.array([income,age,rooms,bedroom,pop])
# Out:
# What is your income 77521
# What is your house age 6.4
# What is your number of rooms 7
# What is your number of bedrooms 5
# What is your area population 33000

# %%
house_price_pred=lr.predict(user_input.reshape(1,-1))
print(f'Your house can be sold between ${round(house_price_pred[0])-50000} to ${round(house_price_pred[0])+50000}')
# Out:
# Your house can be sold between $1400806 to $1500806
# C:\Users\rimas\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
joblib.dump(lr,'USA house price prediction model 100k rmse 25-08-25.pkl')
# Out:
# ['USA house price prediction model 100k rmse 25-08-25.pkl']
